# %% [markdown]
# <a href="https://colab.research.google.com/github/anannya1947/COVID19DeathRateAnalysis/blob/master/ExperimentsWithNormalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tushar

# %%
#Chakri

# %%
#Anannya

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab.patches import cv2_imshow
import cv2 
import matplotlib.pyplot as plt
#hi
img = cv2.imread("/content/drive/MyDrive/Colab_Notebooks/first/data/A1.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=430x430 at 0x7F32342A6D10>

# %%
#Hemanth
